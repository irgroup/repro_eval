# %%
# !pip install repro-eval

# %%
# !cd ../data && ../scripts/get_data.sh

# %%
# !python -m repro_eval --type reproducibility --qrels ../data/qrels/core17.txt --runs ../data/runs/orig/input.WCrobust04 ../data/runs/orig/input.WCrobust0405 ../data/runs/rpd/14/irc_task1_WCrobust04_001 ../data/runs/rpd/14/irc_task1_WCrobust0405_001
# Out:
# Kendall's tau Union (KTU)
# ------------------------------------------------------------------
# KTU                      all     BASE    0.0078    ADV     0.0153
#
# Rank-biased Overlap (RBO)
# ------------------------------------------------------------------
# RBO                      all     BASE    0.6335    ADV     0.7388
#
# Root mean square error (RMSE)
# ------------------------------------------------------------------
# AP                       RMSE    BASE    0.0748    ADV     0.0419
# Rprec                    RMSE    BASE    0.0714    ADV     0.0369
# Bpref                    RMSE    BASE    0.0624    ADV     0.0365
# RR                       RMSE    BASE    0.2495    ADV     0.1856
# IPrec@0.0                RMSE    BASE    0.1616    ADV     0.1012
# IPrec@0.1                RMSE    BASE    0.1364    ADV     0.0808
# IPrec@0.2                RMSE    BASE    0.1284    ADV     0.0805
# IPrec@0.3                RMSE    BASE    0.1240    ADV     0.0812
# ...

# %%
# !python -m repro_eval --type reproducibility --measure rmse --qrels ../data/qrels/core17.txt --runs ../data/runs/orig/input.WCrobust04 ../data/runs/orig/input.WCrobust0405 ../data/runs/rpd/14/irc_task1_WCrobust04_001 ../data/runs/rpd/14/irc_task1_WCrobust0405_001
# Out:
# Root mean square error (RMSE)
# ------------------------------------------------------------------
# AP                       RMSE    BASE    0.0748    ADV     0.0419
# Rprec                    RMSE    BASE    0.0714    ADV     0.0369
# Bpref                    RMSE    BASE    0.0624    ADV     0.0365
# RR                       RMSE    BASE    0.2495    ADV     0.1856
# IPrec@0.0                RMSE    BASE    0.1616    ADV     0.1012
# IPrec@0.1                RMSE    BASE    0.1364    ADV     0.0808
# IPrec@0.2                RMSE    BASE    0.1284    ADV     0.0805
# IPrec@0.3                RMSE    BASE    0.1240    ADV     0.0812
# IPrec@0.4                RMSE    BASE    0.1148    ADV     0.0730
# IPrec@0.5                RMSE    BASE    0.1315    ADV     0.0759
# IPrec@0.6                RMSE    BASE    0.1243    ADV     0.0750
# IPrec@0.7                RMSE    BASE    0.0791    ADV     0.0453
# IPrec@0.8                RMSE    BASE    0.0792    ADV     0.0674
# ...

# %%
# !python -m repro_eval --type reproducibility --measure rmse --qrels ../data/qrels/core17.txt --runs ../data/runs/orig/input.WCrobust04 ../data/runs/rpd/14/irc_task1_WCrobust04_001
# Out:
# Root mean square error (RMSE)
# ------------------------------------------------------------------
# AP                       RMSE    BASE    0.0748
# Rprec                    RMSE    BASE    0.0714
# Bpref                    RMSE    BASE    0.0624
# RR                       RMSE    BASE    0.2495
# IPrec@0.0                RMSE    BASE    0.1616
# IPrec@0.1                RMSE    BASE    0.1364
# IPrec@0.2                RMSE    BASE    0.1284
# IPrec@0.3                RMSE    BASE    0.1240
# IPrec@0.4                RMSE    BASE    0.1148
# IPrec@0.5                RMSE    BASE    0.1315
# IPrec@0.6                RMSE    BASE    0.1243
# IPrec@0.7                RMSE    BASE    0.0791
# IPrec@0.8                RMSE    BASE    0.0792
# IPrec@0.9                RMSE    BASE    0.0888
# IPrec@1.0                RMSE    BASE    0.0013
# P@5                      RMSE    BASE    0.2173
# P@10                     RMSE    BASE    0.2000
# ...

# %%
# !python -m repro_eval --type replicability --qrels ../data/qrels/core17.txt ../data/qrels/core18.txt --runs ../data/runs/orig/input.WCrobust04 ../data/runs/orig/input.WCrobust0405 ../data/runs/rpl/14/irc_task2_WCrobust04_001 ../data/runs/rpl/14/irc_task2_WCrobust0405_001
# Out:
# Effect ratio (ER)
# ------------------------------------------------------------------
# AP                       ER      0.3514
# Rprec                    ER      0.5239
# Bpref                    ER      0.4654
# RR                       ER      0.3401
# IPrec@0.0                ER      0.5609
# IPrec@0.1                ER      0.4451
# IPrec@0.2                ER      0.3261
# IPrec@0.3                ER      0.3613
# IPrec@0.4                ER      0.3608
# IPrec@0.5                ER      0.2040
# IPrec@0.6                ER      0.2508
# IPrec@0.7                ER      0.4939
# IPrec@0.8                ER      0.4796
# IPrec@0.9                ER      0.0606
# IPrec@1.0                ER      0.6142
# P@5                      ER      0.4348
# P@10                     ER      0.2308
# P@15                     ER      0.3521
# P@20                     ER      0.2990
# P@30                     ER      0.2908
# P@100                    ER      0.2065
# ...

# %%
# !python -m repro_eval --type replicability --qrels ../data/qrels/core17.txt ../data/qrels/core18.txt --runs ../data/runs/orig/input.WCrobust04 ../data/runs/rpl/14/irc_task2_WCrobust04_001
# Out:
# Two-tailed unpaired t-test (p-value)
# ------------------------------------------------------------------
# AP                       PVAL    BASE    0.0000
# Rprec                    PVAL    BASE    0.0000
# Bpref                    PVAL    BASE    0.0000
# RR                       PVAL    BASE    0.0000
# IPrec@0.0                PVAL    BASE    0.0000
# IPrec@0.1                PVAL    BASE    0.0000
# IPrec@0.2                PVAL    BASE    0.0000
# IPrec@0.3                PVAL    BASE    0.0000
# IPrec@0.4                PVAL    BASE    0.0000
# IPrec@0.5                PVAL    BASE    0.0000
# IPrec@0.6                PVAL    BASE    0.0000
# IPrec@0.7                PVAL    BASE    0.0000
# IPrec@0.8                PVAL    BASE    0.0000
# IPrec@0.9                PVAL    BASE    0.0004
# IPrec@1.0                PVAL    BASE    0.2631
# P@5                      PVAL    BASE    0.0000
# P@10                     PVAL    BASE    0.0000
# ...
