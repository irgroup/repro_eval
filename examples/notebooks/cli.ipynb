# %%
# !pip install repro-eval

# %%
! wget -h

# %%
# !pwd
# Out:
# /Users/timo/workdir/repro_eval/repro_eval/examples/notebooks

# %%
# !cd /Users/timo/workdir/repro_eval && python -m repro_eval -t rpd -q './qrels/core17.txt' -r './runs/bffmsss.ccrf.04.core17.1.gz' './runs/bffmsss.ccrf.04.core17.2.gz'
# Out:
# Kendall's tau Union (KTU)
# ------------------------------------------------------------------
# KTU                      all     BASE    0.0046
#
# Rank-biased Overlap (RBO)
# ------------------------------------------------------------------
# RBO                      all     BASE    0.4887
#
# Root mean square error (RMSE)
# ------------------------------------------------------------------
# AP                       RMSE    BASE    0.1163
# Rprec                    RMSE    BASE    0.1027
# Bpref                    RMSE    BASE    0.0799
# RR                       RMSE    BASE    0.2855
# IPrec@0.0                RMSE    BASE    0.1866
# IPrec@0.1                RMSE    BASE    0.1774
# IPrec@0.2                RMSE    BASE    0.2032
# IPrec@0.3                RMSE    BASE    0.1890
# IPrec@0.4                RMSE    BASE    0.1812
# IPrec@0.5                RMSE    BASE    0.1798
# IPrec@0.6                RMSE    BASE    0.1647
# IPrec@0.7                RMSE    BASE    0.1463
# ...

# %%
# !python -m repro_eval -t rpd -q './qrels/core17.txt' -r './runs/bffmsss.ccrf.04.core17.1.gz' './runs/bffmsss.ccrf.0405.core17.1.gz' './runs/bffmsss.ccrf.04.core17.2.gz' './runs/bffmsss.ccrf.0405.core17.2.gz'

# %%
# !python -m repro_eval -t rpl -q './qrels/core18.txt' './qrels/core17.txt' -r './runs/uwmrg.gz' './runs/bps.ccrf.ddg_title_desc.core17.uwmrg.gz'

# %%
# !python -m repro_eval -t rpl -q './qrels/core18.txt' './qrels/core17.txt' -r './runs/uwmrg.gz' './runs/uwmrgx.gz' './runs/bps.ccrf.ddg_title_desc.core17.uwmrg.gz' './runs/bps.ccrf.ddg_title_desc.core17.uwmrgx.gz'
